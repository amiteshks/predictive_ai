# %% [markdown]
# ## Ridge Regression on Diabetes Data / Diabetes Prediction

# %%
# pip install scikit-learn pandas

# %%
import pandas as pd

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()

df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# 1   -0.039493 -0.068332 -0.092204
# 2   -0.002592  0.002861 -0.025930
# 3    0.034309  0.022688 -0.009362
# 4   -0.002592 -0.031988 -0.046641
# ..        ...       ...       ...
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064
#
# [442 rows x 10 columns]

# %%
df
df.info()
df.describe()
df.corr()

# %%
X = df.drop(columns='s6')
y = df['s6']

X,y

# %%
from sklearn.model_selection import train_test_split

#Create Train and Test Data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.2)
X_train

# %% [markdown]
# ## Create & Train Model
# model = LinearRegression()
# model.fit(X_train, y_train)
#
# ## Predict
# y_predicted = model.predict(X_test)
#
# ## Evaluate Model Performance
# MAE
# MSE
# RMSE = root_mean_squared_error(y_predicted, y_test)

# %%
#Ridge
from sklearn.linear_model import Ridge

ridge_model = Ridge(alpha = 0.1) # 0.01, 0.1, 0.25, 0.5, 1.0

ridge_model.fit(X_train, y_train)
ridge_model.coef_

# %%
y_predicted = ridge_model.predict(X_test)
y_predicted

# %%
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, mean_squared_error, r2_score
ridge_mae = mean_absolute_error(y_predicted, y_test)
ridge_mse = mean_squared_error(y_predicted, y_test)
ridge_rmse = root_mean_squared_error(y_predicted, y_test)

ridge_mae, ridge_mse, ridge_rmse

# %%
alpha_values = [0.01, 0.1, 0.25, 0.5, 1.0]
for alpha_value in alpha_values:

    ridge_model = Ridge(alpha = alpha_value)

    ridge_model.fit(X_train, y_train)
    # print (f"ridge_model.coef_: {ridge_model.coef_}")


    y_predicted = ridge_model.predict(X_test)

    ridge_mae = mean_absolute_error(y_predicted, y_test)
    ridge_mse = mean_squared_error(y_predicted, y_test)
    ridge_rmse = root_mean_squared_error(y_predicted, y_test)


    print (f"ridge_mae: {ridge_mae}, ridge_mse: {ridge_mse}, ridge_rmse: {ridge_rmse}")
# Out:
# ridge_mae: 0.02963609839397562, ridge_mse: 0.0013992829618249692, ridge_rmse: 0.03740699081488605
# ridge_mae: 0.029700923635452365, ridge_mse: 0.00140861745504235, ridge_rmse: 0.03753155279284818
# ridge_mae: 0.029781010602176992, ridge_mse: 0.0014238750628684856, ridge_rmse: 0.03773426907823293
# ridge_mae: 0.029909549388947326, ridge_mse: 0.00145080045556466, ridge_rmse: 0.0380893745756564
# ridge_mae: 0.03016598558584009, ridge_mse: 0.0015050378536047568, ridge_rmse: 0.03879481735496066
